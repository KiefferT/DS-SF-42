# %% [markdown]
# # DS-SF-34 | 02 | The `pandas` Library | Codealong | Starter Code

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable)

# %% [markdown]
# ## Part A - Introduction to `pandas`

# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# > ## `pd.read_csv()`: load datasets from files (or even over the Internet)

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)

# %%
df = pd.read_csv('../datasets/dataset-02-zillow-starter.csv')

## Awesome - start argument "../" hit tab at each step to get autocomplete options

# %% [markdown]
# > ## `DataFrame`

# %% [markdown]
# Let's check `df`'s type:

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `df` is a `DataFrame`.  (http://pandas.pydata.org/pandas-docs/stable/dsintro.html)

# %% [markdown]
# A `DataFrame` stores tabular data.  Let's have a look at its content:

# %%
df.head()
# Out:
#          ID                                     Address  Latitude  Longitude  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#   DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  \
# 0    12/4/15  710000.00             $     False   1.0    NaN   550.0     sqft
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0     sqft
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0     sqft
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0     sqft
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0     sqft
#
#    LotSize LotSizeUnit  BuiltInYear
# 0      NaN         NaN       1980.0
# 1   2435.0        sqft       1948.0
# 2   3920.0        sqft       1976.0
# 3      NaN         NaN       1930.0
# 4      NaN         NaN       1993.0

# %% [markdown]
# > ## `.head()`: first 5 (default) rows

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.head.html)

# %%
df.head()
# Out:
#          ID                                     Address  Latitude  Longitude  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#   DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  \
# 0    12/4/15  710000.00             $     False   1.0    NaN   550.0     sqft
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0     sqft
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0     sqft
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0     sqft
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0     sqft
#
#    LotSize LotSizeUnit  BuiltInYear
# 0      NaN         NaN       1980.0
# 1   2435.0        sqft       1948.0
# 2   3920.0        sqft       1976.0
# 3      NaN         NaN       1930.0
# 4      NaN         NaN       1993.0

# %% [markdown]
# > ## `.tail()`: last 5 (default) rows

# %%
df.tail()
# Out:
#              ID                                  Address  Latitude  Longitude  \
# 995  2124214951    412 Green St APT A, San Francisco, CA  37800040 -122406100
# 996  2126960082  355 1st St UNIT 1905, San Francisco, CA  37787029 -122393638
# 997  2128308939     33 Santa Cruz Ave, San Francisco, CA  37709136 -122465332
# 998  2131957929        1821 Grant Ave, San Francisco, CA  37803760 -122408531
# 999  2136213970         1200 Gough St, San Francisco, CA  37784770 -122424100
#
#     DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths    Size  \
# 995    1/15/16   390000.0             $      True   NaN    1.0   264.0
# 996   11/20/15   860000.0             $     False   1.0    1.0   691.0
# 997   12/10/15   830000.0             $     False   3.0    3.0  1738.0
# 998   12/15/15   835000.0             $     False   2.0    2.0  1048.0
# 999    1/10/16   825000.0             $     False   1.0    1.0   900.0
#
#     SizeUnit  LotSize LotSizeUnit  BuiltInYear
# 995     sqft      NaN         NaN       2012.0
# 996     sqft      NaN         NaN       2004.0
# 997     sqft   2299.0        sqft       1976.0
# 998     sqft      NaN         NaN       1975.0
# 999     sqft      NaN         NaN       1966.0

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.tail.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.tail.html)

# %%
df.shape  # Note no (), bc shape is an attribute
# Out:
# (1000, 15)

# %% [markdown]
# > ## `.shape`: shape (i.e., number of rows and columns)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.shape.html)

# %%
df.shape
# Out:
# (1000, 15)

# %% [markdown]
# The first value (at index 0) is the number of rows, the second (at index 1), the number of columns:

# %%
df.shape[0]
# Out:
# 1000

# %%
df.shape[1]
# Out:
# 15

# %% [markdown]
# You can also use the idiomatic Python `len` function to get the number of rows:

# %%
len(df)
# Out:
# 1000

# %% [markdown]
# > ## `.dtypes`: column types

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dtypes.html)
# - (http://pandas.pydata.org/pandas-docs/stable/basics.html)

# %%
df.dtypes #Sweet
# Out:
# ID                 int64
# Address           object
# Latitude           int64
# Longitude          int64
# DateOfSale        object
# SalePrice        float64
# SalePriceUnit     object
# IsAStudio         object
# Beds             float64
# Baths            float64
# Size             float64
# SizeUnit          object
# LotSize          float64
# LotSizeUnit       object
# BuiltInYear      float64
# dtype: object

# %% [markdown]
# > ## `.isnull()` and `.notnull()`: NaN (Not-a-Number)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.isnull.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.isnull.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.isnull.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.notnull.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.notnull.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.notnull.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.sum.html)

# %% [markdown]
# As a data scientist, we will have to decide what to do when encountering missing values (a.k.a, not-a-numbers).  We might decide to drop the row containing it, drop the whole column, or impute it.  Today, let's focus on finding these NaNs.

# %%
df.isnull().head()
# Out:
#       ID  Address  Latitude  Longitude  DateOfSale  SalePrice  SalePriceUnit  \
# 0  False    False     False      False       False      False          False
# 1  False    False     False      False       False      False          False
# 2  False    False     False      False       False      False          False
# 3  False    False     False      False       False      False          False
# 4  False    False     False      False       False      False          False
#
#    IsAStudio   Beds  Baths   Size  SizeUnit  LotSize  LotSizeUnit  BuiltInYear
# 0      False  False   True  False     False     True         True        False
# 1      False   True  False  False     False    False        False        False
# 2      False  False  False  False     False    False        False        False
# 3      False  False  False  False     False     True         True        False
# 4      False  False  False  False     False     True         True        False

# %%
type(df.isnull)
# Out:
# instancemethod

# %% [markdown]
# In return, we get a new `DataFrame` with Boolean values.  `True` if the value is `NaN`, `False` otherwise.

# %% [markdown]
# We can also get the count per column:

# %%
df.isnull().sum()
# Out:
# ID                 0
# Address            0
# Latitude           0
# Longitude          0
# DateOfSale         0
# SalePrice          0
# SalePriceUnit      0
# IsAStudio         14
# Beds             164
# Baths             58
# Size              33
# SizeUnit          33
# LotSize          444
# LotSizeUnit      444
# BuiltInYear       25
# dtype: int64

# %%
null_mask = df.isnull()
null_mask.sum(axis = 1).head() # by rows - looking at num of nulls for for first rows of data
# Out:
# 0    3
# 1    1
# 2    0
# 3    2
# 4    2
# dtype: int64

# %%
null_mask.sum(axis = 0)
# Out:
# ID                 0
# Address            0
# Latitude           0
# Longitude          0
# DateOfSale         0
# SalePrice          0
# SalePriceUnit      0
# IsAStudio         14
# Beds             164
# Baths             58
# Size              33
# SizeUnit          33
# LotSize          444
# LotSizeUnit      444
# BuiltInYear       25
# dtype: int64

# %% [markdown]
# Summing again will return the number of cells in the `DataFrame` with missing values.

# %%
null_mask.sum()
# Out:
# ID                 0
# Address            0
# Latitude           0
# Longitude          0
# DateOfSale         0
# SalePrice          0
# SalePriceUnit      0
# IsAStudio         14
# Beds             164
# Baths             58
# Size              33
# SizeUnit          33
# LotSize          444
# LotSizeUnit      444
# BuiltInYear       25
# dtype: int64

# %% [markdown]
# Equivalently, we can also use the `.isnull()` function:

# %%
pd.isnull(df).head() #note passing df as parameter to pandas' isnull function
# Out:
#       ID  Address  Latitude  Longitude  DateOfSale  SalePrice  SalePriceUnit  \
# 0  False    False     False      False       False      False          False
# 1  False    False     False      False       False      False          False
# 2  False    False     False      False       False      False          False
# 3  False    False     False      False       False      False          False
# 4  False    False     False      False       False      False          False
#
#    IsAStudio   Beds  Baths   Size  SizeUnit  LotSize  LotSizeUnit  BuiltInYear
# 0      False  False   True  False     False     True         True        False
# 1      False   True  False  False     False    False        False        False
# 2      False  False  False  False     False    False        False        False
# 3      False  False  False  False     False     True         True        False
# 4      False  False  False  False     False     True         True        False

# %% [markdown]
# We also also use `.notnull()`, its complement method:

# %%
df.notnull().head()
# Out:
#      ID  Address  Latitude  Longitude  DateOfSale  SalePrice  SalePriceUnit  \
# 0  True     True      True       True        True       True           True
# 1  True     True      True       True        True       True           True
# 2  True     True      True       True        True       True           True
# 3  True     True      True       True        True       True           True
# 4  True     True      True       True        True       True           True
#
#    IsAStudio   Beds  Baths  Size  SizeUnit  LotSize  LotSizeUnit  BuiltInYear
# 0       True   True  False  True      True    False        False         True
# 1       True  False   True  True      True     True         True         True
# 2       True   True   True  True      True     True         True         True
# 3       True   True   True  True      True    False        False         True
# 4       True   True   True  True      True    False        False         True

# %%
pd.notnull(df).head()
# Out:
#      ID  Address  Latitude  Longitude  DateOfSale  SalePrice  SalePriceUnit  \
# 0  True     True      True       True        True       True           True
# 1  True     True      True       True        True       True           True
# 2  True     True      True       True        True       True           True
# 3  True     True      True       True        True       True           True
# 4  True     True      True       True        True       True           True
#
#    IsAStudio   Beds  Baths  Size  SizeUnit  LotSize  LotSizeUnit  BuiltInYear
# 0       True   True  False  True      True    False        False         True
# 1       True  False   True  True      True     True         True         True
# 2       True   True   True  True      True     True         True         True
# 3       True   True   True  True      True    False        False         True
# 4       True   True   True  True      True    False        False         True

# %% [markdown]
# > ### `.index` and `.columns`: row and column labels

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.html)

# %% [markdown]
# Use the `.index` property to get the label for rows.  For columns, use the `.columns` property.

# %%
df.index # This output suggests no set index (e.g. ID), just that it's a range
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# In this specific case, rows are just numbered from 0 to 1,000.  Note that, similarly to Python's standard `range` function, this range also excludes the last number.

# %%
df.columns
# Out:
# Index([u'ID', u'Address', u'Latitude', u'Longitude', u'DateOfSale',
#        u'SalePrice', u'SalePriceUnit', u'IsAStudio', u'Beds', u'Baths',
#        u'Size', u'SizeUnit', u'LotSize', u'LotSizeUnit', u'BuiltInYear'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# Fun w/ columns
columns_upper = []
for column in df.columns:
    columns_upper.append(column.upper())
    
columns_upper
# Out:
# ['ID',
#  'ADDRESS',
#  'LATITUDE',
#  'LONGITUDE',
#  'DATEOFSALE',
#  'SALEPRICE',
#  'SALEPRICEUNIT',
#  'ISASTUDIO',
#  'BEDS',
#  'BATHS',
#  'SIZE',
#  'SIZEUNIT',
#  'LOTSIZE',
#  'LOTSIZEUNIT',
#  'BUILTINYEAR']

# %%
df.head()
# Out:
#          ID                                     Address  Latitude  Longitude  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#   DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  \
# 0    12/4/15  710000.00             $     False   1.0    NaN   550.0     sqft
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0     sqft
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0     sqft
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0     sqft
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0     sqft
#
#    LotSize LotSizeUnit  BuiltInYear
# 0      NaN         NaN       1980.0
# 1   2435.0        sqft       1948.0
# 2   3920.0        sqft       1976.0
# 3      NaN         NaN       1930.0
# 4      NaN         NaN       1993.0

# %%
df.columns = columns_upper #setting colnames

# %%
df.head(10)
# Out:
#          ID                                     ADDRESS  LATITUDE  LONGITUDE  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
# 5  15064295  111 Chestnut St APT 702, San Francisco, CA  37804240 -122405509
# 6  15064391   1821 Grant Ave APT 101, San Francisco, CA  37803748 -122408531
# 7  15064536      2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 8  15064640     1047-1049 Lombard St, San Francisco, CA  37801889 -122418704
# 9  15064669      1055 Lombard St # C, San Francisco, CA  37801873 -122418834
#
#   DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE SIZEUNIT  \
# 0    12/4/15  710000.00             $     False   1.0    NaN   550.0     sqft
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0     sqft
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0     sqft
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0     sqft
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0     sqft
# 5   12/17/15  940000.00             $     False   2.0    2.0  1033.0     sqft
# 6   12/15/15  835000.00             $     False   1.0    1.0  1048.0     sqft
# 7    12/4/15       2.83            $M     False   3.0    2.0  2115.0     sqft
# 8    1/14/16       4.05            $M      True   NaN    NaN  4102.0     sqft
# 9   12/31/15       2.19            $M     False   2.0    3.0  1182.0     sqft
#
#    LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# 0      NaN         NaN       1980.0
# 1   2435.0        sqft       1948.0
# 2   3920.0        sqft       1976.0
# 3      NaN         NaN       1930.0
# 4      NaN         NaN       1993.0
# 5      NaN         NaN       1993.0
# 6      NaN         NaN       1975.0
# 7   1271.0        sqft       1913.0
# 8   3049.0        sqft       1948.0
# 9      NaN         NaN       1986.0

# %% [markdown]
# > ## `[ [] ]` and `[]`: subsetting on columns

# %% [markdown]
# Selecting specific columns is performed by using the `[]` operator.
#
# Passing a single integer, or a list of integers, to `[]` will perform a location-based lookup of the columns.

# %% [markdown]
# > E.g., columns #5 and #6:

# %%
# By Name
df["LATITUDE"].head()
# Out:
# 0    37805103
# 1    37804420
# 2    37803728
# 3    37804392
# 4    37804240
# Name: LATITUDE, dtype: int64

# %% [markdown]
# > Let's check that the column subsetting returns a `DataFrame`:

# %%
df_lat = df["LATITUDE"]
type(df_lat)
# Out:
# pandas.core.series.Series

# %%
df_lat.head()
# Out:
# 0    37805103
# 1    37804420
# 2    37803728
# 3    37804392
# 4    37804240
# Name: LATITUDE, dtype: int64

# %%
df[["LATITUDE", "LONGITUDE"]].head(10) # NOTE: double quotes Create list of columns to subset
# Out:
#    LATITUDE  LONGITUDE
# 0  37805103 -122412856
# 1  37804420 -122417389
# 2  37803728 -122419055
# 3  37804392 -122406590
# 4  37804240 -122405509
# 5  37804240 -122405509
# 6  37803748 -122408531
# 7  37802408 -122417537
# 8  37801889 -122418704
# 9  37801873 -122418834

# %%
df[["SALEPRICE", "SALEPRICEUNIT"]].head(10)
# Out:
#    SALEPRICE SALEPRICEUNIT
# 0  710000.00             $
# 1       2.15            $M
# 2       5.60            $M
# 3       1.50            $M
# 4  970000.00             $
# 5  940000.00             $
# 6  835000.00             $
# 7       2.83            $M
# 8       4.05            $M
# 9       2.19            $M

# %%
df['ADDRESS'].head(10)
# Out:
# 0     55 Vandewater St APT 9, San Francisco, CA
# 1           740 Francisco St, San Francisco, CA
# 2           819 Francisco St, San Francisco, CA
# 3      199 Chestnut St APT 5, San Francisco, CA
# 4    111 Chestnut St APT 403, San Francisco, CA
# 5    111 Chestnut St APT 702, San Francisco, CA
# 6     1821 Grant Ave APT 101, San Francisco, CA
# 7        2300 Leavenworth St, San Francisco, CA
# 8       1047-1049 Lombard St, San Francisco, CA
# 9        1055 Lombard St # C, San Francisco, CA
# Name: ADDRESS, dtype: object

# %%
type(df['ADDRESS'])
# Out:
# pandas.core.series.Series

# %%
df[['ADDRESS']].head(10) # Note double [[]] makes nice df-like
# Out:
#                                       ADDRESS
# 0   55 Vandewater St APT 9, San Francisco, CA
# 1         740 Francisco St, San Francisco, CA
# 2         819 Francisco St, San Francisco, CA
# 3    199 Chestnut St APT 5, San Francisco, CA
# 4  111 Chestnut St APT 403, San Francisco, CA
# 5  111 Chestnut St APT 702, San Francisco, CA
# 6   1821 Grant Ave APT 101, San Francisco, CA
# 7      2300 Leavenworth St, San Francisco, CA
# 8     1047-1049 Lombard St, San Francisco, CA
# 9      1055 Lombard St # C, San Francisco, CA

# %%
type(df[['ADDRESS']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# > Note that a `DataFrame` can be made of a single column.  E.g., column #7 only:

# %%
df.ID.head()
# Out:
# 0    15063471
# 1    15063505
# 2    15063609
# 3    15064044
# 4    15064257
# Name: ID, dtype: int64

# %% [markdown]
# If the values passed to `[]` are non-integers, the `DataFrame` will attempt to match them to those in the `columns` property.

# %% [markdown]
# > Let's subset the `DataFrame` on columns `SalePrice` and `SalePriceUnit`:

# %%
df[["SALEPRICE", "SALEPRICEUNIT"]].head()
# Out:
#    SALEPRICE SALEPRICEUNIT
# 0  710000.00             $
# 1       2.15            $M
# 2       5.60            $M
# 3       1.50            $M
# 4  970000.00             $

# %%
df.columns.get_loc('BEDS') # Where is beds columns
# Out:
# 8

# %% [markdown]
# However, you cannot mix integers and non-integers.  E.g.,

# %%
# "df[ ['SalePrice', 6] ]" errors out...  Try it!
df[["SALEPRICE", 6]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-6f823f6c0988> in <module>()
#       1 # "df[ ['SalePrice', 6] ]" errors out...  Try it!
# ----> 2 df[["SALEPRICE", 6]]
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: '[6] not in index'

# %%
# All ints doesn't seem to work either (though they work w/ standard [][] indexing as ranges, not sure on lists)
df[[3 , 4]].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-751e670ee7e3> in <module>()
#       1 # All ints doesn't seem to work either (though they work w/ standard [][] indexing as ranges, not sure on lists)
# ----> 2 df[[3 , 4]].head()
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: '[3 4] not in index'

# %% [markdown]
# Not passing a list always results in a value-based lookup of the column:

# %%
df[['ADDRESS']].head()
# Out:
#                                       ADDRESS
# 0   55 Vandewater St APT 9, San Francisco, CA
# 1         740 Francisco St, San Francisco, CA
# 2         819 Francisco St, San Francisco, CA
# 3    199 Chestnut St APT 5, San Francisco, CA
# 4  111 Chestnut St APT 403, San Francisco, CA

# %% [markdown]
# > ## `Series`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/dsintro.html)

# %% [markdown]
# > Let's check the result type:

# %%
type(df[["ADDRESS"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Columns can also be retrieved using "attribute" access as `DataFrame`s add a property for each column with the names of the properties as the names of the columns.  This won't work however for columns that have spaces or dots in their name.

# %% [markdown]
# > Let's check the value of `df`'s `.Address` property:

# %%
df.ADDRESS
# Out:
# 0         55 Vandewater St APT 9, San Francisco, CA
# 1               740 Francisco St, San Francisco, CA
# 2               819 Francisco St, San Francisco, CA
# 3          199 Chestnut St APT 5, San Francisco, CA
# 4        111 Chestnut St APT 403, San Francisco, CA
# 5        111 Chestnut St APT 702, San Francisco, CA
# 6         1821 Grant Ave APT 101, San Francisco, CA
# 7            2300 Leavenworth St, San Francisco, CA
# 8           1047-1049 Lombard St, San Francisco, CA
# 9            1055 Lombard St # C, San Francisco, CA
# 10       101 Lombard St APT 116E, San Francisco, CA
# 11      1407 Montgomery St APT 2, San Francisco, CA
# 12      1360 Montgomery St APT 1, San Francisco, CA
# 13           1327-1329 Kearny St, San Francisco, CA
# 14        44 Macondray Ln APT 2E, San Francisco, CA
# 15         1070 Green St APT 201, San Francisco, CA
# 16        1070 Green St APT 1402, San Francisco, CA
# 17     1907 Leavenworth St APT 8, San Francisco, CA
# 18           1101 Green St # 303, San Francisco, CA
# 19                 1807 Jones St, San Francisco, CA
# 20          999 Green St APT 905, San Francisco, CA
# 21        455 Vallejo St APT 111, San Francisco, CA
# 22          1163-1165 Vallejo St, San Francisco, CA
# 23              1300 Pacific Ave, San Francisco, CA
# 24                948 Jackson St, San Francisco, CA
# 25        946 Stockton St APT 6B, San Francisco, CA
# 26        946 Stockton St APT 9E, San Francisco, CA
# 27          1250 Clay St APT 306, San Francisco, CA
# 28         1250 Jones St APT 503, San Francisco, CA
# 29         1250 Jones St APT 802, San Francisco, CA
#                            ...
# 970                 2137 Pine St, San Francisco, CA
# 971                409 Miguel St, San Francisco, CA
# 972              251 Missouri St, San Francisco, CA
# 973              1650 Florida St, San Francisco, CA
# 974            41 Collingwood St, San Francisco, CA
# 975               2753 Bryant St, San Francisco, CA
# 976              244 Precita Ave, San Francisco, CA
# 977                  6 Rossi Ave, San Francisco, CA
# 978              333 Potrero Ave, San Francisco, CA
# 979                1340 Union St, San Francisco, CA
# 980              688 Douglass St, San Francisco, CA
# 981                414 Linden St, San Francisco, CA
# 982        1408 31st Ave APT 303, San Francisco, CA
# 983                 333 Beale St, San Francisco, CA
# 984               82 Alvarado St, San Francisco, CA
# 985           2619 Sacramento St, San Francisco, CA
# 986              129 Central Ave, San Francisco, CA
# 987                444 Linden St, San Francisco, CA
# 988                2595 38th Ave, San Francisco, CA
# 989                 3500 19th St, San Francisco, CA
# 990        1738 Lombard St APT 4, San Francisco, CA
# 991      201 Sansome St UNIT 501, San Francisco, CA
# 992                925 Larkin St, San Francisco, CA
# 993       829 Folsom St UNIT 906, San Francisco, CA
# 994               129 Octavia St, San Francisco, CA
# 995           412 Green St APT A, San Francisco, CA
# 996         355 1st St UNIT 1905, San Francisco, CA
# 997            33 Santa Cruz Ave, San Francisco, CA
# 998               1821 Grant Ave, San Francisco, CA
# 999                1200 Gough St, San Francisco, CA
# Name: ADDRESS, Length: 1000, dtype: object

# %% [markdown]
# > Use the `.name` property (not `.columns`, that's for a `DataFrame`) to get the name of the variable stored inside it.

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.name.html)

# %%
df.SALEPRICEUNIT.name
# Out:
# 'SALEPRICEUNIT'

# %% [markdown]
# > To find the zero-based location of a column, use the `.get_loc()` method of the `.columns` property.  E.g.,

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.get_loc.html)

# %%
df.columns.get_loc('BEDS')
# Out:
# 8

# %%
df[ [df.columns.get_loc('BEDS')] ] # Again, ints don't work
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-bb671be7454a> in <module>()
# ----> 1 df[ [df.columns.get_loc('BEDS')] ] # Again, ints don't work
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: '[8] not in index'

# %% [markdown]
# We should get the same output as subsetting a `DataFrame` on `Beds`:

# %%
# TODO

# %% [markdown]
# > ## `[]`: slicing on rows

# %% [markdown]
# > E.g., on the first five rows:

# %%
df[1:5]
# Out:
#          ID                                     ADDRESS  LATITUDE  LONGITUDE  \
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#   DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE SIZEUNIT  \
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0     sqft
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0     sqft
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0     sqft
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0     sqft
#
#    LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# 1   2435.0        sqft       1948.0
# 2   3920.0        sqft       1976.0
# 3      NaN         NaN       1930.0
# 4      NaN         NaN       1993.0

# %%
df[1:5][["ADDRESS", "LATITUDE", "LONGITUDE"]]
# Out:
#                                       ADDRESS  LATITUDE  LONGITUDE
# 1         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509

# %% [markdown]
# > ## `.loc[]` and `.iloc[]`: subsetting rows by index label and location

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.loc.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.iloc.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.iloc.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.set_index.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.set_index.html)

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.reset_index.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.reset_index.html)

# %% [markdown]
# Until now, the index of the `DataFrame` is a numerical starting from 0 but you can specify which column(s) should be in the index.

# %% [markdown]
# > E.g., `ID`:

# %%
df.head()
# Out:
#          ID                                     ADDRESS  LATITUDE  LONGITUDE  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#   DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE SIZEUNIT  \
# 0    12/4/15  710000.00             $     False   1.0    NaN   550.0     sqft
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0     sqft
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0     sqft
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0     sqft
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0     sqft
#
#    LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# 0      NaN         NaN       1980.0
# 1   2435.0        sqft       1948.0
# 2   3920.0        sqft       1976.0
# 3      NaN         NaN       1930.0
# 4      NaN         NaN       1993.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df = df.set_index('ID') # Here we set the ID in df to be the index

# %%
df.index
# Out:
# Int64Index([  15063471,   15063505,   15063609,   15064044,   15064257,
#               15064295,   15064391,   15064536,   15064640,   15064669,
#             ...
#             2108546010, 2114498518, 2121221385, 2121978635, 2122992200,
#             2124214951, 2126960082, 2128308939, 2131957929, 2136213970],
#            dtype='int64', name=u'ID', length=1000)

# %%
df.head(10) # Note no more row nums now that we have an index
# Out:
#                                              ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
# 15064295  111 Chestnut St APT 702, San Francisco, CA  37804240 -122405509
# 15064391   1821 Grant Ave APT 101, San Francisco, CA  37803748 -122408531
# 15064536      2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 15064640     1047-1049 Lombard St, San Francisco, CA  37801889 -122418704
# 15064669      1055 Lombard St # C, San Francisco, CA  37801873 -122418834
#
#          DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15063471    12/4/15  710000.00             $     False   1.0    NaN   550.0
# 15063505   11/30/15       2.15            $M     False   NaN    2.0  1430.0
# 15063609   11/12/15       5.60            $M     False   2.0    3.5  2040.0
# 15064044   12/11/15       1.50            $M     False   1.0    1.0  1060.0
# 15064257    1/15/16  970000.00             $     False   2.0    2.0  1299.0
# 15064295   12/17/15  940000.00             $     False   2.0    2.0  1033.0
# 15064391   12/15/15  835000.00             $     False   1.0    1.0  1048.0
# 15064536    12/4/15       2.83            $M     False   3.0    2.0  2115.0
# 15064640    1/14/16       4.05            $M      True   NaN    NaN  4102.0
# 15064669   12/31/15       2.19            $M     False   2.0    3.0  1182.0
#
#          SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15063471     sqft      NaN         NaN       1980.0
# 15063505     sqft   2435.0        sqft       1948.0
# 15063609     sqft   3920.0        sqft       1976.0
# 15064044     sqft      NaN         NaN       1930.0
# 15064257     sqft      NaN         NaN       1993.0
# 15064295     sqft      NaN         NaN       1993.0
# 15064391     sqft      NaN         NaN       1975.0
# 15064536     sqft   1271.0        sqft       1913.0
# 15064640     sqft   3049.0        sqft       1948.0
# 15064669     sqft      NaN         NaN       1986.0

# %% [markdown]
# > E.g., row with index 15063505:

# %%
df.loc[15063505 , "SALEPRICE"]   # [rows to select, columns to select]
# Out:
# 2.1499999999999999

# %%
df.loc[15063505]
# Out:
# ADDRESS          740 Francisco St, San Francisco, CA
# LATITUDE                                    37804420
# LONGITUDE                                 -122417389
# DATEOFSALE                                  11/30/15
# SALEPRICE                                       2.15
# SALEPRICEUNIT                                     $M
# ISASTUDIO                                      False
# BEDS                                             NaN
# BATHS                                              2
# SIZE                                            1430
# SIZEUNIT                                        sqft
# LOTSIZE                                         2435
# LOTSIZEUNIT                                     sqft
# BUILTINYEAR                                     1948
# Name: 15063505, dtype: object

# %%
df.loc[15063505, ["LATITUDE", "LONGITUDE"]]
# Out:
# LATITUDE       37804420
# LONGITUDE    -122417389
# Name: 15063505, dtype: object

# %%
df.loc[[15063505, 15064044]]
# Out:
#                                            ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15063505       740 Francisco St, San Francisco, CA  37804420 -122417389
# 15064044  199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
#
#          DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15063505   11/30/15       2.15            $M     False   NaN    2.0  1430.0
# 15064044   12/11/15       1.50            $M     False   1.0    1.0  1060.0
#
#          SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15063505     sqft   2435.0        sqft       1948.0
# 15064044     sqft      NaN         NaN       1930.0

# %% [markdown]
# Its name is its value in the index.

# %% [markdown]
# > E.g., rows with indices 15063505 and 15064044:

# %%
df.loc[[15063505, 15064044] , ["DATEOFSALE", "SALEPRICE"]]
# Out:
#          DATEOFSALE  SALEPRICE
# ID
# 15063505   11/30/15       2.15
# 15064044   12/11/15       1.50

# %%
type(df.loc[[15063505, 15064044] , ["DATEOFSALE", "SALEPRICE"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[[15063505, 15064044] , :] # Get all cols
# Out:
#                                            ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15063505       740 Francisco St, San Francisco, CA  37804420 -122417389
# 15064044  199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
#
#          DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15063505   11/30/15       2.15            $M     False   NaN    2.0  1430.0
# 15064044   12/11/15       1.50            $M     False   1.0    1.0  1060.0
#
#          SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15063505     sqft   2435.0        sqft       1948.0
# 15064044     sqft      NaN         NaN       1930.0

# %% [markdown]
# E.g., rows #1 and #3:

# %%
df.iloc[[1, 3]]
# Out:
#                                            ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15063505       740 Francisco St, San Francisco, CA  37804420 -122417389
# 15064044  199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
#
#          DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15063505   11/30/15       2.15            $M     False   NaN    2.0  1430.0
# 15064044   12/11/15       1.50            $M     False   1.0    1.0  1060.0
#
#          SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15063505     sqft   2435.0        sqft       1948.0
# 15064044     sqft      NaN         NaN       1930.0

# %%
# Or a bunch of rows

df.iloc[[1, 3, 5, 7, 9]]
# Out:
#                                              ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064295  111 Chestnut St APT 702, San Francisco, CA  37804240 -122405509
# 15064536      2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 15064669      1055 Lombard St # C, San Francisco, CA  37801873 -122418834
#
#          DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15063505   11/30/15       2.15            $M     False   NaN    2.0  1430.0
# 15064044   12/11/15       1.50            $M     False   1.0    1.0  1060.0
# 15064295   12/17/15  940000.00             $     False   2.0    2.0  1033.0
# 15064536    12/4/15       2.83            $M     False   3.0    2.0  2115.0
# 15064669   12/31/15       2.19            $M     False   2.0    3.0  1182.0
#
#          SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15063505     sqft   2435.0        sqft       1948.0
# 15064044     sqft      NaN         NaN       1930.0
# 15064295     sqft      NaN         NaN       1993.0
# 15064536     sqft   1271.0        sqft       1913.0
# 15064669     sqft      NaN         NaN       1986.0

# %%
df.iloc[50:100, 5:10].head()
# Out:
#          SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE
# ID
# 15071199            $M     False   4.0    5.0  4178.0
# 15071224            $M     False   2.0    2.0  1367.0
# 15071286            $M     False   2.0    2.0  1150.0
# 15071577            $M     False   3.0    3.5  3105.0
# 15072128            $M     False   2.0    2.0  1206.0

# %% [markdown]
# > ## Subsetting rows by Boolean selection (a.k.a., masking)

# %% [markdown]
# Rows can also be selected by using Boolean selection, using an array calculated from the result of applying a logical condition on the values in any of the columns.  This allows us to build more complicated selections than those based simply upon index labels or positions.

# %% [markdown]
# > E.g., what homes have been built before 1900?

# %%
# Select by built in year

df["BUILTINYEAR"] > 1900
# Out:
# ID
# 15063471       True
# 15063505       True
# 15063609       True
# 15064044       True
# 15064257       True
# 15064295       True
# 15064391       True
# 15064536       True
# 15064640       True
# 15064669       True
# 15065032       True
# 15065140      False
# 15065727       True
# 15065810       True
# 15065946       True
# 15066001       True
# 15066036       True
# 15066085       True
# 15066201       True
# 15066281       True
# 15066344       True
# 15066608       True
# 15066839       True
# 15066959       True
# 15067302       True
# 15067583       True
# 15067604       True
# 15067755       True
# 15067890       True
# 15067896       True
#               ...
# 2100992607    False
# 2100994004    False
# 2101028916    False
# 2101094207     True
# 2101105851     True
# 2101116542    False
# 2101147349     True
# 2101153805     True
# 2101156735     True
# 2101167573     True
# 2101169168     True
# 2101175813     True
# 2101331127     True
# 2101505254     True
# 2101588805    False
# 2101807538    False
# 2102385068     True
# 2102906272    False
# 2106229715     True
# 2108411930     True
# 2108546010     True
# 2114498518     True
# 2121221385     True
# 2121978635     True
# 2122992200    False
# 2124214951     True
# 2126960082     True
# 2128308939     True
# 2131957929     True
# 2136213970     True
# Name: BUILTINYEAR, Length: 1000, dtype: bool

# %%
# Play with this

year_built = df["BUILTINYEAR"]

df.loc[df["BUILTINYEAR"] < 1900, :]
# Out:
#                                                 ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15065140    1407 Montgomery St APT 2, San Francisco, CA  37802299 -122404941
# 15076156              1533 Sutter St, San Francisco, CA  37786658 -122426481
# 15078536              640 Steiner St, San Francisco, CA  37775399 -122432491
# 15078866              753-755 Oak St, San Francisco, CA  37773576 -122431663
# 15082108          3016 Sacramento St, San Francisco, CA  37788970 -122442995
# 15084954        1954 Golden Gate Ave, San Francisco, CA  37778420 -122443073
# 15145720          956 S Van Ness Ave, San Francisco, CA  37757832 -122417139
# 15181209     1001 Diamond St # 1001A, San Francisco, CA  37749461 -122435844
# 63197592                3021 20th St, San Francisco, CA  37758878 -122411147
# 82785514          1394 Mcallister St, San Francisco, CA  37778463 -122434933
# 114318108          1442 Grove St # A, San Francisco, CA  37775894 -122440467
# 119684777               967 Hayes St, San Francisco, CA  37775645 -122432222
# 123597223       1954 Golden Gate Ave, San Francisco, CA  37778246 -122442763
# 123597388        667 Shotwell St # A, San Francisco, CA  37757851 -122415629
# 2122992200            129 Octavia St, San Francisco, CA  37773192 -122424037
#
#            DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15065140      1/28/16  976000.00             $     False   1.0    1.0  1000.0
# 15076156     11/12/15       5.53            $M     False   6.0    7.5  7375.0
# 15078536     12/15/15       1.50            $M     False   2.0    2.0  1593.0
# 15078866     11/10/15  375000.00             $     False   NaN    2.0  2430.0
# 15082108     12/22/15       1.85            $M     False   2.0    1.5  1408.0
# 15084954     11/24/15       1.10            $M     False   2.0    1.0  1515.0
# 15145720     11/23/15       2.67            $M     False   4.0    4.0  3500.0
# 15181209     11/24/15       3.10            $M     False   3.0    2.0  2032.0
# 63197592      12/7/15       1.10            $M     False   1.0    2.0  1267.0
# 82785514     11/13/15       2.10            $M     False   3.0    2.5  2300.0
# 114318108    12/24/15  675000.00             $     False   1.0    1.0   593.0
# 119684777    12/17/15       1.95            $M     False   4.0    3.0  3006.0
# 123597223    11/24/15       1.10            $M     False   2.0    1.0  1275.0
# 123597388     2/10/16  775000.00             $     False   1.0    1.0  1212.0
# 2122992200   11/20/15       2.75            $M      True   NaN    NaN  3655.0
#
#            SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15065140       sqft      NaN         NaN       1870.0
# 15076156       sqft   2748.0        sqft       1890.0
# 15078536       sqft      NaN         NaN       1895.0
# 15078866       sqft   3781.0        sqft       1890.0
# 15082108       sqft      NaN         NaN       1890.0
# 15084954       sqft      NaN         NaN       1895.0
# 15145720       sqft   4165.0        sqft       1872.0
# 15181209       sqft   1913.0        sqft       1892.0
# 63197592       sqft      NaN         NaN       1890.0
# 82785514       sqft      NaN         NaN       1890.0
# 114318108      sqft      NaN         NaN       1890.0
# 119684777      sqft      NaN         NaN       1885.0
# 123597223      sqft      NaN         NaN       1895.0
# 123597388      sqft      NaN         NaN       1890.0
# 2122992200     sqft      NaN         NaN       1883.0

# %%
year_built.head()
# Out:
# ID
# 15063471    1980.0
# 15063505    1948.0
# 15063609    1976.0
# 15064044    1930.0
# 15064257    1993.0
# Name: BUILTINYEAR, dtype: float64

# %%
type(year_built)
# Out:
# pandas.core.series.Series

# %%
year_built_mask = year_built < 1900

df[year_built_mask].head(10)
# Out:
#                                               ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15065140  1407 Montgomery St APT 2, San Francisco, CA  37802299 -122404941
# 15076156            1533 Sutter St, San Francisco, CA  37786658 -122426481
# 15078536            640 Steiner St, San Francisco, CA  37775399 -122432491
# 15078866            753-755 Oak St, San Francisco, CA  37773576 -122431663
# 15082108        3016 Sacramento St, San Francisco, CA  37788970 -122442995
# 15084954      1954 Golden Gate Ave, San Francisco, CA  37778420 -122443073
# 15145720        956 S Van Ness Ave, San Francisco, CA  37757832 -122417139
# 15181209   1001 Diamond St # 1001A, San Francisco, CA  37749461 -122435844
# 63197592              3021 20th St, San Francisco, CA  37758878 -122411147
# 82785514        1394 Mcallister St, San Francisco, CA  37778463 -122434933
#
#          DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15065140    1/28/16  976000.00             $     False   1.0    1.0  1000.0
# 15076156   11/12/15       5.53            $M     False   6.0    7.5  7375.0
# 15078536   12/15/15       1.50            $M     False   2.0    2.0  1593.0
# 15078866   11/10/15  375000.00             $     False   NaN    2.0  2430.0
# 15082108   12/22/15       1.85            $M     False   2.0    1.5  1408.0
# 15084954   11/24/15       1.10            $M     False   2.0    1.0  1515.0
# 15145720   11/23/15       2.67            $M     False   4.0    4.0  3500.0
# 15181209   11/24/15       3.10            $M     False   3.0    2.0  2032.0
# 63197592    12/7/15       1.10            $M     False   1.0    2.0  1267.0
# 82785514   11/13/15       2.10            $M     False   3.0    2.5  2300.0
#
#          SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15065140     sqft      NaN         NaN       1870.0
# 15076156     sqft   2748.0        sqft       1890.0
# 15078536     sqft      NaN         NaN       1895.0
# 15078866     sqft   3781.0        sqft       1890.0
# 15082108     sqft      NaN         NaN       1890.0
# 15084954     sqft      NaN         NaN       1895.0
# 15145720     sqft   4165.0        sqft       1872.0
# 15181209     sqft   1913.0        sqft       1892.0
# 63197592     sqft      NaN         NaN       1890.0
# 82785514     sqft      NaN         NaN       1890.0

# %%
# OR use "~" to do not mask (in this case year built > 1900)

df[~year_built_mask].head(10)
# Out:
#                                              ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
# 15064295  111 Chestnut St APT 702, San Francisco, CA  37804240 -122405509
# 15064391   1821 Grant Ave APT 101, San Francisco, CA  37803748 -122408531
# 15064536      2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 15064640     1047-1049 Lombard St, San Francisco, CA  37801889 -122418704
# 15064669      1055 Lombard St # C, San Francisco, CA  37801873 -122418834
#
#          DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15063471    12/4/15  710000.00             $     False   1.0    NaN   550.0
# 15063505   11/30/15       2.15            $M     False   NaN    2.0  1430.0
# 15063609   11/12/15       5.60            $M     False   2.0    3.5  2040.0
# 15064044   12/11/15       1.50            $M     False   1.0    1.0  1060.0
# 15064257    1/15/16  970000.00             $     False   2.0    2.0  1299.0
# 15064295   12/17/15  940000.00             $     False   2.0    2.0  1033.0
# 15064391   12/15/15  835000.00             $     False   1.0    1.0  1048.0
# 15064536    12/4/15       2.83            $M     False   3.0    2.0  2115.0
# 15064640    1/14/16       4.05            $M      True   NaN    NaN  4102.0
# 15064669   12/31/15       2.19            $M     False   2.0    3.0  1182.0
#
#          SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15063471     sqft      NaN         NaN       1980.0
# 15063505     sqft   2435.0        sqft       1948.0
# 15063609     sqft   3920.0        sqft       1976.0
# 15064044     sqft      NaN         NaN       1930.0
# 15064257     sqft      NaN         NaN       1993.0
# 15064295     sqft      NaN         NaN       1993.0
# 15064391     sqft      NaN         NaN       1975.0
# 15064536     sqft   1271.0        sqft       1913.0
# 15064640     sqft   3049.0        sqft       1948.0
# 15064669     sqft      NaN         NaN       1986.0

# %%
saleprice_mask = df["SALEPRICE"] < 10

year_built_mask & saleprice_mask # Note we're looking at the index & if both these condiditions are true, also how masks are tight
# Out:
# ID
# 15063471      False
# 15063505      False
# 15063609      False
# 15064044      False
# 15064257      False
# 15064295      False
# 15064391      False
# 15064536      False
# 15064640      False
# 15064669      False
# 15065032      False
# 15065140      False
# 15065727      False
# 15065810      False
# 15065946      False
# 15066001      False
# 15066036      False
# 15066085      False
# 15066201      False
# 15066281      False
# 15066344      False
# 15066608      False
# 15066839      False
# 15066959      False
# 15067302      False
# 15067583      False
# 15067604      False
# 15067755      False
# 15067890      False
# 15067896      False
#               ...
# 2100992607    False
# 2100994004    False
# 2101028916    False
# 2101094207    False
# 2101105851    False
# 2101116542    False
# 2101147349    False
# 2101153805    False
# 2101156735    False
# 2101167573    False
# 2101169168    False
# 2101175813    False
# 2101331127    False
# 2101505254    False
# 2101588805    False
# 2101807538    False
# 2102385068    False
# 2102906272    False
# 2106229715    False
# 2108411930    False
# 2108546010    False
# 2114498518    False
# 2121221385    False
# 2121978635    False
# 2122992200     True
# 2124214951    False
# 2126960082    False
# 2128308939    False
# 2131957929    False
# 2136213970    False
# Length: 1000, dtype: bool

# %%
df.loc[year_built_mask & saleprice_mask, :] # Mask w/ df.loc work as conditionals in a pretty awesome way
# Out:
#                                                ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15076156             1533 Sutter St, San Francisco, CA  37786658 -122426481
# 15078536             640 Steiner St, San Francisco, CA  37775399 -122432491
# 15082108         3016 Sacramento St, San Francisco, CA  37788970 -122442995
# 15084954       1954 Golden Gate Ave, San Francisco, CA  37778420 -122443073
# 15145720         956 S Van Ness Ave, San Francisco, CA  37757832 -122417139
# 15181209    1001 Diamond St # 1001A, San Francisco, CA  37749461 -122435844
# 63197592               3021 20th St, San Francisco, CA  37758878 -122411147
# 82785514         1394 Mcallister St, San Francisco, CA  37778463 -122434933
# 119684777              967 Hayes St, San Francisco, CA  37775645 -122432222
# 123597223      1954 Golden Gate Ave, San Francisco, CA  37778246 -122442763
# 2122992200           129 Octavia St, San Francisco, CA  37773192 -122424037
#
#            DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15076156     11/12/15       5.53            $M     False   6.0    7.5  7375.0
# 15078536     12/15/15       1.50            $M     False   2.0    2.0  1593.0
# 15082108     12/22/15       1.85            $M     False   2.0    1.5  1408.0
# 15084954     11/24/15       1.10            $M     False   2.0    1.0  1515.0
# 15145720     11/23/15       2.67            $M     False   4.0    4.0  3500.0
# 15181209     11/24/15       3.10            $M     False   3.0    2.0  2032.0
# 63197592      12/7/15       1.10            $M     False   1.0    2.0  1267.0
# 82785514     11/13/15       2.10            $M     False   3.0    2.5  2300.0
# 119684777    12/17/15       1.95            $M     False   4.0    3.0  3006.0
# 123597223    11/24/15       1.10            $M     False   2.0    1.0  1275.0
# 2122992200   11/20/15       2.75            $M      True   NaN    NaN  3655.0
#
#            SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15076156       sqft   2748.0        sqft       1890.0
# 15078536       sqft      NaN         NaN       1895.0
# 15082108       sqft      NaN         NaN       1890.0
# 15084954       sqft      NaN         NaN       1895.0
# 15145720       sqft   4165.0        sqft       1872.0
# 15181209       sqft   1913.0        sqft       1892.0
# 63197592       sqft      NaN         NaN       1890.0
# 82785514       sqft      NaN         NaN       1890.0
# 119684777      sqft      NaN         NaN       1885.0
# 123597223      sqft      NaN         NaN       1895.0
# 2122992200     sqft      NaN         NaN       1883.0

# %%
df.loc[year_built_mask & saleprice_mask, ["SALEPRICE", "SALEPRICEUNIT"]].head()
# Out:
#           SALEPRICE SALEPRICEUNIT
# ID
# 15076156       5.53            $M
# 15078536       1.50            $M
# 15082108       1.85            $M
# 15084954       1.10            $M
# 15145720       2.67            $M

# %%
df.loc[year_built_mask & saleprice_mask, :].shape
# Out:
# (11, 14)

# %% [markdown]
# > Let's subset on that `Series`:

# %%
df.loc[year_built_mask | saleprice_mask, :].head() # using | or operator
# Out:
#                                            ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15063505       740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609       819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064044  199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064536    2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 15064640   1047-1049 Lombard St, San Francisco, CA  37801889 -122418704
#
#          DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15063505   11/30/15       2.15            $M     False   NaN    2.0  1430.0
# 15063609   11/12/15       5.60            $M     False   2.0    3.5  2040.0
# 15064044   12/11/15       1.50            $M     False   1.0    1.0  1060.0
# 15064536    12/4/15       2.83            $M     False   3.0    2.0  2115.0
# 15064640    1/14/16       4.05            $M      True   NaN    NaN  4102.0
#
#          SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15063505     sqft   2435.0        sqft       1948.0
# 15063609     sqft   3920.0        sqft       1976.0
# 15064044     sqft      NaN         NaN       1930.0
# 15064536     sqft   1271.0        sqft       1913.0
# 15064640     sqft   3049.0        sqft       1948.0

# %%
df.loc[year_built_mask | saleprice_mask, :].shape
# Out:
# (574, 14)

# %% [markdown]
# Multiple conditions can be put together.

# %% [markdown]
# > E.g., subset for `BuiltInYear` below 1900 and `Size` over 1500:

# %%
df.loc[(df["BUILTINYEAR"] < 1900) & (df["SIZE"] > 1500)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-9311e6fb3848> in <module>()
# ----> 1 df.loc[(df["BUILTINYEAR"] < 1900) & (df["SIZE"] > 1500)]
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BUILTINYEAR'

# %% [markdown]
# It is possible to subset on columns simultaneously.

# %% [markdown]
# > E.g., subset (a `DataFrame`) on `Address` for `BuiltInYear` below 1900 and `Size` over 1500:

# %%
df.loc[(df["BUILTINYEAR"] < 1900) & (df["SIZEUNIT"] > 1500)]
# Out:
#                                                 ADDRESS  LATITUDE  LONGITUDE  \
# ID
# 15065140    1407 Montgomery St APT 2, San Francisco, CA  37802299 -122404941
# 15076156              1533 Sutter St, San Francisco, CA  37786658 -122426481
# 15078536              640 Steiner St, San Francisco, CA  37775399 -122432491
# 15078866              753-755 Oak St, San Francisco, CA  37773576 -122431663
# 15082108          3016 Sacramento St, San Francisco, CA  37788970 -122442995
# 15084954        1954 Golden Gate Ave, San Francisco, CA  37778420 -122443073
# 15145720          956 S Van Ness Ave, San Francisco, CA  37757832 -122417139
# 15181209     1001 Diamond St # 1001A, San Francisco, CA  37749461 -122435844
# 63197592                3021 20th St, San Francisco, CA  37758878 -122411147
# 82785514          1394 Mcallister St, San Francisco, CA  37778463 -122434933
# 114318108          1442 Grove St # A, San Francisco, CA  37775894 -122440467
# 119684777               967 Hayes St, San Francisco, CA  37775645 -122432222
# 123597223       1954 Golden Gate Ave, San Francisco, CA  37778246 -122442763
# 123597388        667 Shotwell St # A, San Francisco, CA  37757851 -122415629
# 2122992200            129 Octavia St, San Francisco, CA  37773192 -122424037
#
#            DATEOFSALE  SALEPRICE SALEPRICEUNIT ISASTUDIO  BEDS  BATHS    SIZE  \
# ID
# 15065140      1/28/16  976000.00             $     False   1.0    1.0  1000.0
# 15076156     11/12/15       5.53            $M     False   6.0    7.5  7375.0
# 15078536     12/15/15       1.50            $M     False   2.0    2.0  1593.0
# 15078866     11/10/15  375000.00             $     False   NaN    2.0  2430.0
# 15082108     12/22/15       1.85            $M     False   2.0    1.5  1408.0
# 15084954     11/24/15       1.10            $M     False   2.0    1.0  1515.0
# 15145720     11/23/15       2.67            $M     False   4.0    4.0  3500.0
# 15181209     11/24/15       3.10            $M     False   3.0    2.0  2032.0
# 63197592      12/7/15       1.10            $M     False   1.0    2.0  1267.0
# 82785514     11/13/15       2.10            $M     False   3.0    2.5  2300.0
# 114318108    12/24/15  675000.00             $     False   1.0    1.0   593.0
# 119684777    12/17/15       1.95            $M     False   4.0    3.0  3006.0
# 123597223    11/24/15       1.10            $M     False   2.0    1.0  1275.0
# 123597388     2/10/16  775000.00             $     False   1.0    1.0  1212.0
# 2122992200   11/20/15       2.75            $M      True   NaN    NaN  3655.0
#
#            SIZEUNIT  LOTSIZE LOTSIZEUNIT  BUILTINYEAR
# ID
# 15065140       sqft      NaN         NaN       1870.0
# 15076156       sqft   2748.0        sqft       1890.0
# 15078536       sqft      NaN         NaN       1895.0
# 15078866       sqft   3781.0        sqft       1890.0
# 15082108       sqft      NaN         NaN       1890.0
# 15084954       sqft      NaN         NaN       1895.0
# 15145720       sqft   4165.0        sqft       1872.0
# 15181209       sqft   1913.0        sqft       1892.0
# 63197592       sqft      NaN         NaN       1890.0
# 82785514       sqft      NaN         NaN       1890.0
# 114318108      sqft      NaN         NaN       1890.0
# 119684777      sqft      NaN         NaN       1885.0
# 123597223      sqft      NaN         NaN       1895.0
# 123597388      sqft      NaN         NaN       1890.0
# 2122992200     sqft      NaN         NaN       1883.0

# %% [markdown]
# > To get a `Series` instead of a `DataFrame`:

# %%
# TODO

# %% [markdown]
# ## Part B - Wrangling the SF Housing dataset (take 2) with `pandas`

# %%
df = pd.read_csv('../datasets/dataset-02-zillow-starter.csv', index_col = 'ID')  # Sets index w/ param
df2 = df #creating my own copy of df to work through

# %%
df2.columns
# Out:
# Index([u'Address', u'Latitude', u'Longitude', u'DateOfSale', u'SalePrice',
#        u'SalePriceUnit', u'IsAStudio', u'Beds', u'Baths', u'Size', u'SizeUnit',
#        u'LotSize', u'LotSizeUnit', u'BuiltInYear'],
#       dtype='object')

# %% [markdown]
# (`pd.read_csv` can load the dataset and set the index column for the `DataFrame` at the same time)

# %% [markdown]
# > ### Remove the `Latitude` and `Longitude` columns

# %%
df2.drop(["Latitude", "Longitude"], axis = 1).head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15  710000.00
# 15063505         740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609         819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064044    199 Chestnut St APT 5, San Francisco, CA   12/11/15       1.50
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16  970000.00
#
#          SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  LotSize  \
# ID
# 15063471             $     False   1.0    NaN   550.0     sqft      NaN
# 15063505            $M     False   NaN    2.0  1430.0     sqft   2435.0
# 15063609            $M     False   2.0    3.5  2040.0     sqft   3920.0
# 15064044            $M     False   1.0    1.0  1060.0     sqft      NaN
# 15064257             $     False   2.0    2.0  1299.0     sqft      NaN
#
#          LotSizeUnit  BuiltInYear
# ID
# 15063471         NaN       1980.0
# 15063505        sqft       1948.0
# 15063609        sqft       1976.0
# 15064044         NaN       1930.0
# 15064257         NaN       1993.0

# %%
df2.head() # Just noting here that df2 does not actually change unless we assign it to drop
# Out:
#                                              Address  Latitude  Longitude  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#          DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths    Size  \
# ID
# 15063471    12/4/15  710000.00             $     False   1.0    NaN   550.0
# 15063505   11/30/15       2.15            $M     False   NaN    2.0  1430.0
# 15063609   11/12/15       5.60            $M     False   2.0    3.5  2040.0
# 15064044   12/11/15       1.50            $M     False   1.0    1.0  1060.0
# 15064257    1/15/16  970000.00             $     False   2.0    2.0  1299.0
#
#          SizeUnit  LotSize LotSizeUnit  BuiltInYear
# ID
# 15063471     sqft      NaN         NaN       1980.0
# 15063505     sqft   2435.0        sqft       1948.0
# 15063609     sqft   3920.0        sqft       1976.0
# 15064044     sqft      NaN         NaN       1930.0
# 15064257     sqft      NaN         NaN       1993.0

# %%
df2 = df2.drop(["Latitude", "Longitude"], axis = 1) # Note can use inplace param to do without assignment
df2.head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15  710000.00
# 15063505         740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609         819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064044    199 Chestnut St APT 5, San Francisco, CA   12/11/15       1.50
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16  970000.00
#
#          SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  LotSize  \
# ID
# 15063471             $     False   1.0    NaN   550.0     sqft      NaN
# 15063505            $M     False   NaN    2.0  1430.0     sqft   2435.0
# 15063609            $M     False   2.0    3.5  2040.0     sqft   3920.0
# 15064044            $M     False   1.0    1.0  1060.0     sqft      NaN
# 15064257             $     False   2.0    2.0  1299.0     sqft      NaN
#
#          LotSizeUnit  BuiltInYear
# ID
# 15063471         NaN       1980.0
# 15063505        sqft       1948.0
# 15063609        sqft       1976.0
# 15064044         NaN       1930.0
# 15064257         NaN       1993.0

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html)

# %%
df.drop(['Latitude', 'Longitude'], axis = 1, inplace = True) # axis = 1 is cols, will not actually drop them unless inplace

# %%
df.head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15  710000.00
# 15063505         740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609         819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064044    199 Chestnut St APT 5, San Francisco, CA   12/11/15       1.50
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16  970000.00
#
#          SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  LotSize  \
# ID
# 15063471             $     False   1.0    NaN   550.0     sqft      NaN
# 15063505            $M     False   NaN    2.0  1430.0     sqft   2435.0
# 15063609            $M     False   2.0    3.5  2040.0     sqft   3920.0
# 15064044            $M     False   1.0    1.0  1060.0     sqft      NaN
# 15064257             $     False   2.0    2.0  1299.0     sqft      NaN
#
#          LotSizeUnit  BuiltInYear
# ID
# 15063471         NaN       1980.0
# 15063505        sqft       1948.0
# 15063609        sqft       1976.0
# 15064044         NaN       1930.0
# 15064257         NaN       1993.0

# %% [markdown]
# > ### `SalePrice`: scale all amount to `$M`

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.unique.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.concat.html)
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_index.html)

# %%
df2.SalePriceUnit.unique()
# Out:
# array(['$', '$M'], dtype=object)

# %%
million_mask = df2["SalePriceUnit"] == "$"
million_mask.head()
# Out:
# ID
# 15063471     True
# 15063505    False
# 15063609    False
# 15064044    False
# 15064257     True
# Name: SalePriceUnit, dtype: bool

# %%
dfMil = df2[million_mask]
dfMil.head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15   710000.0
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16   970000.0
# 15064295  111 Chestnut St APT 702, San Francisco, CA   12/17/15   940000.0
# 15064391   1821 Grant Ave APT 101, San Francisco, CA   12/15/15   835000.0
# 15065032  101 Lombard St APT 116E, San Francisco, CA    12/7/15   800000.0
#
#          SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  LotSize  \
# ID
# 15063471             $     False   1.0    NaN   550.0     sqft      NaN
# 15064257             $     False   2.0    2.0  1299.0     sqft      NaN
# 15064295             $     False   2.0    2.0  1033.0     sqft      NaN
# 15064391             $     False   1.0    1.0  1048.0     sqft      NaN
# 15065032             $     False   1.0    1.0  1000.0     sqft      NaN
#
#          LotSizeUnit  BuiltInYear
# ID
# 15063471         NaN       1980.0
# 15064257         NaN       1993.0
# 15064295         NaN       1993.0
# 15064391         NaN       1975.0
# 15065032         NaN       1983.0

# %%
dfMil.SalePrice = dfMil.SalePrice / 1000000 # Keeping warning below as it's interesting; should keep in mind next time
dfMil.head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15      0.710
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16      0.970
# 15064295  111 Chestnut St APT 702, San Francisco, CA   12/17/15      0.940
# 15064391   1821 Grant Ave APT 101, San Francisco, CA   12/15/15      0.835
# 15065032  101 Lombard St APT 116E, San Francisco, CA    12/7/15      0.800
#
#          SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  LotSize  \
# ID
# 15063471             $     False   1.0    NaN   550.0     sqft      NaN
# 15064257             $     False   2.0    2.0  1299.0     sqft      NaN
# 15064295             $     False   2.0    2.0  1033.0     sqft      NaN
# 15064391             $     False   1.0    1.0  1048.0     sqft      NaN
# 15065032             $     False   1.0    1.0  1000.0     sqft      NaN
#
#          LotSizeUnit  BuiltInYear
# ID
# 15063471         NaN       1980.0
# 15064257         NaN       1993.0
# 15064295         NaN       1993.0
# 15064391         NaN       1975.0
# 15065032         NaN       1983.0

# %%
# Drop SalePriceUnit from dfMil

dfMil = dfMil.drop(["SalePriceUnit"], axis = 1)
dfMil.head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15      0.710
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16      0.970
# 15064295  111 Chestnut St APT 702, San Francisco, CA   12/17/15      0.940
# 15064391   1821 Grant Ave APT 101, San Francisco, CA   12/15/15      0.835
# 15065032  101 Lombard St APT 116E, San Francisco, CA    12/7/15      0.800
#
#          IsAStudio  Beds  Baths    Size SizeUnit  LotSize LotSizeUnit  \
# ID
# 15063471     False   1.0    NaN   550.0     sqft      NaN         NaN
# 15064257     False   2.0    2.0  1299.0     sqft      NaN         NaN
# 15064295     False   2.0    2.0  1033.0     sqft      NaN         NaN
# 15064391     False   1.0    1.0  1048.0     sqft      NaN         NaN
# 15065032     False   1.0    1.0  1000.0     sqft      NaN         NaN
#
#           BuiltInYear
# ID
# 15063471       1980.0
# 15064257       1993.0
# 15064295       1993.0
# 15064391       1975.0
# 15065032       1983.0

# %%
# Now let's get a the df that's alread in $M
dfInMil = df2[~million_mask]
dfInMil.head()
# Out:
#                                            Address DateOfSale  SalePrice  \
# ID
# 15063505       740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609       819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064044  199 Chestnut St APT 5, San Francisco, CA   12/11/15       1.50
# 15064536    2300 Leavenworth St, San Francisco, CA    12/4/15       2.83
# 15064640   1047-1049 Lombard St, San Francisco, CA    1/14/16       4.05
#
#          SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  LotSize  \
# ID
# 15063505            $M     False   NaN    2.0  1430.0     sqft   2435.0
# 15063609            $M     False   2.0    3.5  2040.0     sqft   3920.0
# 15064044            $M     False   1.0    1.0  1060.0     sqft      NaN
# 15064536            $M     False   3.0    2.0  2115.0     sqft   1271.0
# 15064640            $M      True   NaN    NaN  4102.0     sqft   3049.0
#
#          LotSizeUnit  BuiltInYear
# ID
# 15063505        sqft       1948.0
# 15063609        sqft       1976.0
# 15064044         NaN       1930.0
# 15064536        sqft       1913.0
# 15064640        sqft       1948.0

# %%
# Dropping SalePriceUnit from dfInMil
dfInMil.drop(["SalePriceUnit"], axis = 1, inplace = True)
dfInMil.head()
# Out:
# /Users/kiefferthomas/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                            Address DateOfSale  SalePrice  \
# ID
# 15063505       740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609       819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064044  199 Chestnut St APT 5, San Francisco, CA   12/11/15       1.50
# 15064536    2300 Leavenworth St, San Francisco, CA    12/4/15       2.83
# 15064640   1047-1049 Lombard St, San Francisco, CA    1/14/16       4.05
#
#          IsAStudio  Beds  Baths    Size SizeUnit  LotSize LotSizeUnit  \
# ID
# 15063505     False   NaN    2.0  1430.0     sqft   2435.0        sqft
# 15063609     False   2.0    3.5  2040.0     sqft   3920.0        sqft
# 15064044     False   1.0    1.0  1060.0     sqft      NaN         NaN
# 15064536     False   3.0    2.0  2115.0     sqft   1271.0        sqft
# 15064640      True   NaN    NaN  4102.0     sqft   3049.0        sqft
#
#           BuiltInYear
# ID
# 15063505       1948.0
# 15063609       1976.0
# 15064044       1930.0
# 15064536       1913.0
# 15064640       1948.0

# %%
# Let's just make sure names line up then read ahead and see how to join these bad boys
list(dfMil.columns)
# Out:
# ['Address',
#  'DateOfSale',
#  'SalePrice',
#  'IsAStudio',
#  'Beds',
#  'Baths',
#  'Size',
#  'SizeUnit',
#  'LotSize',
#  'LotSizeUnit',
#  'BuiltInYear']

# %%
list(dfInMil.columns) # Looking good
# Out:
# ['Address',
#  'DateOfSale',
#  'SalePrice',
#  'IsAStudio',
#  'Beds',
#  'Baths',
#  'Size',
#  'SizeUnit',
#  'LotSize',
#  'LotSizeUnit',
#  'BuiltInYear']

# %%
df.SalePriceUnit.unique()
# Out:
# array(['$', '$M'], dtype=object)

# %%
df_1 = df[df.SalePriceUnit == '$'] 
df_1 = df_1.drop('SalePriceUnit', axis = 1)

# Scaling sale price to $M
df_1.SalePrice /= 10 ** 6

df_1.head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15      0.710
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16      0.970
# 15064295  111 Chestnut St APT 702, San Francisco, CA   12/17/15      0.940
# 15064391   1821 Grant Ave APT 101, San Francisco, CA   12/15/15      0.835
# 15065032  101 Lombard St APT 116E, San Francisco, CA    12/7/15      0.800
#
#          IsAStudio  Beds  Baths    Size SizeUnit  LotSize LotSizeUnit  \
# ID
# 15063471     False   1.0    NaN   550.0     sqft      NaN         NaN
# 15064257     False   2.0    2.0  1299.0     sqft      NaN         NaN
# 15064295     False   2.0    2.0  1033.0     sqft      NaN         NaN
# 15064391     False   1.0    1.0  1048.0     sqft      NaN         NaN
# 15065032     False   1.0    1.0  1000.0     sqft      NaN         NaN
#
#           BuiltInYear
# ID
# 15063471       1980.0
# 15064257       1993.0
# 15064295       1993.0
# 15064391       1975.0
# 15065032       1983.0

# %%
df_6 = df[df.SalePriceUnit == '$M']
df_6 = df_6.drop('SalePriceUnit', axis = 1)

df_6.head()
# Out:
#                                            Address DateOfSale  SalePrice  \
# ID
# 15063505       740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609       819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064044  199 Chestnut St APT 5, San Francisco, CA   12/11/15       1.50
# 15064536    2300 Leavenworth St, San Francisco, CA    12/4/15       2.83
# 15064640   1047-1049 Lombard St, San Francisco, CA    1/14/16       4.05
#
#          IsAStudio  Beds  Baths    Size SizeUnit  LotSize LotSizeUnit  \
# ID
# 15063505     False   NaN    2.0  1430.0     sqft   2435.0        sqft
# 15063609     False   2.0    3.5  2040.0     sqft   3920.0        sqft
# 15064044     False   1.0    1.0  1060.0     sqft      NaN         NaN
# 15064536     False   3.0    2.0  2115.0     sqft   1271.0        sqft
# 15064640      True   NaN    NaN  4102.0     sqft   3049.0        sqft
#
#           BuiltInYear
# ID
# 15063505       1948.0
# 15063609       1976.0
# 15064044       1930.0
# 15064536       1913.0
# 15064640       1948.0

# %%
# Concatenate of two DataFrames by rows
df = pd.concat([df_1, df_6])

# %%
# Resort the new DataFrame
df.sort_index(inplace = True)

# %%
df.head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15       0.71
# 15063505         740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609         819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064044    199 Chestnut St APT 5, San Francisco, CA   12/11/15       1.50
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16       0.97
#
#          IsAStudio  Beds  Baths    Size SizeUnit  LotSize LotSizeUnit  \
# ID
# 15063471     False   1.0    NaN   550.0     sqft      NaN         NaN
# 15063505     False   NaN    2.0  1430.0     sqft   2435.0        sqft
# 15063609     False   2.0    3.5  2040.0     sqft   3920.0        sqft
# 15064044     False   1.0    1.0  1060.0     sqft      NaN         NaN
# 15064257     False   2.0    2.0  1299.0     sqft      NaN         NaN
#
#           BuiltInYear
# ID
# 15063471       1980.0
# 15063505       1948.0
# 15063609       1976.0
# 15064044       1930.0
# 15064257       1993.0

# %% [markdown]
# > ### `IsAStudio`: convert from a Boolean to a binary variable (i.e., 0 or 1)

# %%
df.IsAStudio.head()
# Out:
# ID
# 15063471    False
# 15063505    False
# 15063609    False
# 15064044    False
# 15064257    False
# Name: IsAStudio, dtype: object

# %%
df.IsAStudio.sum()
# Out:
# 29

# %%
df.IsAStudio.map({True:1, False:0})
# Out:
# ID
# 15063471      0.0
# 15063505      0.0
# 15063609      0.0
# 15064044      0.0
# 15064257      0.0
# 15064295      0.0
# 15064391      0.0
# 15064536      0.0
# 15064640      1.0
# 15064669      0.0
# 15065032      0.0
# 15065140      0.0
# 15065727      0.0
# 15065810      0.0
# 15065946      0.0
# 15066001      0.0
# 15066036      0.0
# 15066085      0.0
# 15066201      0.0
# 15066281      0.0
# 15066344      0.0
# 15066608      0.0
# 15066839      0.0
# 15066959      1.0
# 15067302      0.0
# 15067583      0.0
# 15067604      0.0
# 15067755      0.0
# 15067890      0.0
# 15067896      0.0
#              ...
# 2100992607    0.0
# 2100994004    0.0
# 2101028916    0.0
# 2101094207    0.0
# 2101105851    0.0
# 2101116542    0.0
# 2101147349    0.0
# 2101153805    0.0
# 2101156735    1.0
# 2101167573    0.0
# 2101169168    1.0
# 2101175813    0.0
# 2101331127    0.0
# 2101505254    0.0
# 2101588805    0.0
# 2101807538    1.0
# 2102385068    0.0
# 2102906272    NaN
# 2106229715    0.0
# 2108411930    0.0
# 2108546010    0.0
# 2114498518    0.0
# 2121221385    0.0
# 2121978635    0.0
# 2122992200    1.0
# 2124214951    1.0
# 2126960082    0.0
# 2128308939    0.0
# 2131957929    0.0
# 2136213970    0.0
# Name: IsAStudio, Length: 1000, dtype: float64

# %% [markdown]
# > ### `Size`

# %%
df.SizeUnit.unique()
# Out:
# array(['sqft', nan], dtype=object)

# %% [markdown]
# Size is either in square feet or missing.  Almost no work needed except to remove size unit.

# %%
df.drop('SizeUnit', axis = 1, inplace = True)

# %% [markdown]
# > ### `LotSize`: scale all values to square feet

# %%
# Convert Acres to sqft

df.LotSizeUnit.unique()
# Out:
# array([nan, 'sqft', 'ac'], dtype=object)

# %%
df_sqft = df[df.LotSizeUnit == 'sqft']
df_ac = df[df.LotSizeUnit == 'ac']

df_sqft.head()
# Out:
#                                           Address DateOfSale  SalePrice  \
# ID
# 15063505      740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609      819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064536   2300 Leavenworth St, San Francisco, CA    12/4/15       2.83
# 15064640  1047-1049 Lombard St, San Francisco, CA    1/14/16       4.05
# 15065810   1327-1329 Kearny St, San Francisco, CA   11/25/15       2.25
#
#          IsAStudio  Beds  Baths    Size  LotSize LotSizeUnit  BuiltInYear
# ID
# 15063505     False   NaN    2.0  1430.0   2435.0        sqft       1948.0
# 15063609     False   2.0    3.5  2040.0   3920.0        sqft       1976.0
# 15064536     False   3.0    2.0  2115.0   1271.0        sqft       1913.0
# 15064640      True   NaN    NaN  4102.0   3049.0        sqft       1948.0
# 15065810     False   NaN    4.0  2658.0   1600.0        sqft       1906.0

# %% [markdown]
# Lot sizes are either in square feet or in acres.  Let's convert them all to square feet.

# %% [markdown]
# > Group #1: the `na` values:

# %%
df_na = df[df.LotSizeUnit.isnull()]
df_na = df_na.drop('LotSizeUnit', axis = 1) # But why??

df_na.shape[0]
# Out:
# 444

# %%
df_na.head()
# Out:
#                                              Address DateOfSale  SalePrice  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    12/4/15      0.710
# 15064044    199 Chestnut St APT 5, San Francisco, CA   12/11/15      1.500
# 15064257  111 Chestnut St APT 403, San Francisco, CA    1/15/16      0.970
# 15064295  111 Chestnut St APT 702, San Francisco, CA   12/17/15      0.940
# 15064391   1821 Grant Ave APT 101, San Francisco, CA   12/15/15      0.835
#
#          IsAStudio  Beds  Baths    Size  LotSize  BuiltInYear
# ID
# 15063471     False   1.0    NaN   550.0      NaN       1980.0
# 15064044     False   1.0    1.0  1060.0      NaN       1930.0
# 15064257     False   2.0    2.0  1299.0      NaN       1993.0
# 15064295     False   2.0    2.0  1033.0      NaN       1993.0
# 15064391     False   1.0    1.0  1048.0      NaN       1975.0

# %% [markdown]
# > Group #2: the `sqft` values:

# %%
df_sqft.head()
# Out:
#                                           Address DateOfSale  SalePrice  \
# ID
# 15063505      740 Francisco St, San Francisco, CA   11/30/15       2.15
# 15063609      819 Francisco St, San Francisco, CA   11/12/15       5.60
# 15064536   2300 Leavenworth St, San Francisco, CA    12/4/15       2.83
# 15064640  1047-1049 Lombard St, San Francisco, CA    1/14/16       4.05
# 15065810   1327-1329 Kearny St, San Francisco, CA   11/25/15       2.25
#
#          IsAStudio  Beds  Baths    Size  LotSize LotSizeUnit  BuiltInYear
# ID
# 15063505     False   NaN    2.0  1430.0   2435.0        sqft       1948.0
# 15063609     False   2.0    3.5  2040.0   3920.0        sqft       1976.0
# 15064536     False   3.0    2.0  2115.0   1271.0        sqft       1913.0
# 15064640      True   NaN    NaN  4102.0   3049.0        sqft       1948.0
# 15065810     False   NaN    4.0  2658.0   1600.0        sqft       1906.0

# %% [markdown]
# > Group #3: the `ac` values:

# %%
df_ac.head()
# Out:
#                                        Address DateOfSale  SalePrice  \
# ID
# 15080894   2950 Pacific Ave, San Francisco, CA   11/25/15     16.000
# 15089098        22 22nd Ave, San Francisco, CA   11/17/15      4.970
# 79844263         555 4th St, San Francisco, CA   11/16/15      0.788
# 124865970  255 Woodside Ave, San Francisco, CA   11/16/15     24.900
#
#           IsAStudio  Beds  Baths     Size  LotSize LotSizeUnit  BuiltInYear
# ID
# 15080894      False   7.0    6.5  11500.0     0.28          ac       1907.0
# 15089098      False   5.0    5.0   5610.0     0.32          ac       1926.0
# 79844263      False   1.0    1.0    670.0     1.00          ac       2006.0
# 124865970       NaN   NaN    NaN      NaN     1.10          ac       1900.0

# %% [markdown]
# > Let's scale these `acre` values into `sqft`:

# %%
df_ac.LotSize *= 43560

df_ac.head()
# Out:
#                                        Address DateOfSale  SalePrice  \
# ID
# 15080894   2950 Pacific Ave, San Francisco, CA   11/25/15     16.000
# 15089098        22 22nd Ave, San Francisco, CA   11/17/15      4.970
# 79844263         555 4th St, San Francisco, CA   11/16/15      0.788
# 124865970  255 Woodside Ave, San Francisco, CA   11/16/15     24.900
#
#           IsAStudio  Beds  Baths     Size  LotSize LotSizeUnit  BuiltInYear
# ID
# 15080894      False   7.0    6.5  11500.0  12196.8          ac       1907.0
# 15089098      False   5.0    5.0   5610.0  13939.2          ac       1926.0
# 79844263      False   1.0    1.0    670.0  43560.0          ac       2006.0
# 124865970       NaN   NaN    NaN      NaN  47916.0          ac       1900.0

# %% [markdown]
# Let's now put everything back together...

# %%
df = pd.concat([df_na, df_sqft, df_ac]).sort_index() # Note inline sort

# %%
df.head()
# Out:
#                                              Address  Baths  Beds  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA    NaN   1.0
# 15063505         740 Francisco St, San Francisco, CA    2.0   NaN
# 15063609         819 Francisco St, San Francisco, CA    3.5   2.0
# 15064044    199 Chestnut St APT 5, San Francisco, CA    1.0   1.0
# 15064257  111 Chestnut St APT 403, San Francisco, CA    2.0   2.0
#
#           BuiltInYear DateOfSale IsAStudio  LotSize LotSizeUnit  SalePrice  \
# ID
# 15063471       1980.0    12/4/15     False      NaN         NaN       0.71
# 15063505       1948.0   11/30/15     False   2435.0        sqft       2.15
# 15063609       1976.0   11/12/15     False   3920.0        sqft       5.60
# 15064044       1930.0   12/11/15     False      NaN         NaN       1.50
# 15064257       1993.0    1/15/16     False      NaN         NaN       0.97
#
#             Size
# ID
# 15063471   550.0
# 15063505  1430.0
# 15063609  2040.0
# 15064044  1060.0
# 15064257  1299.0

# %% [markdown]
# > ## `.to_csv`: save the `DataFrame` into a `.csv` file

# %% [markdown]
# At the end of each phase (i.e., wrangling) of your data science project, it is a good idea to save your dataset into disk.  Then for the next step, create a new Jupyther notebook and load your updated dataset

# %%
df.to_csv(os.path.join('..', 'datasets', 'dataset-02-zillow.csv'), index_label = 'ID')

# %% [markdown]
# ## Part C - More advanced topics

# %% [markdown]
# ### `.groupby()`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/groupby.html)

# %% [markdown]
# > What is the mean price of houses by number of bedrooms?

# %%
df = pd.read_csv("../datasets/dataset-02-zillow-starter.csv")

# %%
df[ ['Beds', 'SalePrice'] ].groupby('Beds').mean()
# Out:
#           SalePrice
# Beds
# 1.0   607889.536479
# 2.0   301386.004937
# 3.0   203395.448717
# 4.0   162923.997961
# 5.0   163794.382500
# 6.0    72780.292222
# 7.0    43172.333333
# 8.0        1.960000
# 9.0        1.766667

# %% [markdown]
# ### `.map()`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html)

# %% [markdown]
# When converting `SalePrice`, `Size`, and `LotSize` into `$M` and sqft, we could also have done the following:

# %%
import os

df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-02-zillow-starter.csv'))

# %%
df.SalePriceUnit.unique()
# Out:
# array(['$', '$M'], dtype=object)

# %%
df.SalePriceUnit.map({'$': 1. / (10 ** 6), '$M': 1.}) # Note this is like conditional mutation (nice!), didn't work here
# Out:
# 0      0.000001
# 1      1.000000
# 2      1.000000
# 3      1.000000
# 4      0.000001
# 5      0.000001
# 6      0.000001
# 7      1.000000
# 8      1.000000
# 9      1.000000
# 10     0.000001
# 11     0.000001
# 12     0.000001
# 13     1.000000
# 14     1.000000
# 15     1.000000
# 16     1.000000
# 17     0.000001
# 18     1.000000
# 19     1.000000
# 20     1.000000
# 21     0.000001
# 22     0.000001
# 23     0.000001
# 24     1.000000
# 25     0.000001
# 26     0.000001
# 27     0.000001
# 28     1.000000
# 29     1.000000
#          ...
# 970    1.000000
# 971    0.000001
# 972    1.000000
# 973    0.000001
# 974    1.000000
# 975    1.000000
# 976    0.000001
# 977    1.000000
# 978    1.000000
# 979    1.000000
# 980    1.000000
# 981    0.000001
# 982    0.000001
# 983    1.000000
# 984    0.000001
# 985    1.000000
# 986    1.000000
# 987    0.000001
# 988    1.000000
# 989    1.000000
# 990    1.000000
# 991    0.000001
# 992    1.000000
# 993    0.000001
# 994    1.000000
# 995    0.000001
# 996    0.000001
# 997    0.000001
# 998    0.000001
# 999    0.000001
# Name: SalePriceUnit, Length: 1000, dtype: float64

# %%
df.SalePrice *= df.SalePriceUnit.map({'$': 1. / (10 ** 6), '$M': 1.})

# %%
df.SalePrice
# Out:
# 0      0.7100
# 1      2.1500
# 2      5.6000
# 3      1.5000
# 4      0.9700
# 5      0.9400
# 6      0.8350
# 7      2.8300
# 8      4.0500
# 9      2.1900
# 10     0.8000
# 11     0.9760
# 12     0.7200
# 13     2.2500
# 14     1.2900
# 15     2.9000
# 16     2.6000
# 17     0.9080
# 18     1.2100
# 19     1.7000
# 20     1.2800
# 21     0.8750
# 22     0.3000
# 23     0.4250
# 24     1.9500
# 25     0.7750
# 26     0.7050
# 27     0.6950
# 28     1.4100
# 29     1.6800
#         ...
# 970    1.5500
# 971    0.5100
# 972    2.4500
# 973    0.9700
# 974    1.3000
# 975    1.7000
# 976    0.7850
# 977    1.1500
# 978    1.1400
# 979    1.2500
# 980    3.1500
# 981    0.8350
# 982    0.8900
# 983    1.4000
# 984    0.7500
# 985    2.9000
# 986    1.8000
# 987    0.0058
# 988    1.2400
# 989    1.7300
# 990    1.4000
# 991    0.7575
# 992    1.4300
# 993    0.6750
# 994    2.7500
# 995    0.3900
# 996    0.8600
# 997    0.8300
# 998    0.8350
# 999    0.8250
# Name: SalePrice, Length: 1000, dtype: float64

# %%
df.drop('SalePriceUnit', axis = 1, inplace = True)

# %% [markdown]
# > ### Activity:  Using `.map()`, convert `Size` and `LotSize` to sqft.

# %%
df = pd.read_csv("../datasets/dataset-02-zillow-starter.csv")

# %%
df.head()
# Out:
#          ID                                     Address  Latitude  Longitude  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#   DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths    Size SizeUnit  \
# 0    12/4/15  710000.00             $     False   1.0    NaN   550.0     sqft
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0     sqft
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0     sqft
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0     sqft
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0     sqft
#
#    LotSize LotSizeUnit  BuiltInYear
# 0      NaN         NaN       1980.0
# 1   2435.0        sqft       1948.0
# 2   3920.0        sqft       1976.0
# 3      NaN         NaN       1930.0
# 4      NaN         NaN       1993.0

# %%
df.SizeUnit.unique() # All good for size units
# Out:
# array(['sqft', nan], dtype=object)

# %%
df.drop("SizeUnit", axis = 1, inplace = True) # Drop it
df.head()
# Out:
#          ID                                     Address  Latitude  Longitude  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#   DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths    Size  LotSize  \
# 0    12/4/15  710000.00             $     False   1.0    NaN   550.0      NaN
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0   2435.0
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0   3920.0
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0      NaN
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0      NaN
#
#   LotSizeUnit  BuiltInYear
# 0         NaN       1980.0
# 1        sqft       1948.0
# 2        sqft       1976.0
# 3         NaN       1930.0
# 4         NaN       1993.0

# %%
df.LotSizeUnit.unique()
# Out:
# array([nan, 'sqft', 'ac'], dtype=object)

# %%
df.LotSize *= df.LotSizeUnit.map({"ac" : 1. * 43560})

df.head()
# Out:
#          ID                                     Address  Latitude  Longitude  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#   DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths    Size  LotSize  \
# 0    12/4/15  710000.00             $     False   1.0    NaN   550.0      NaN
# 1   11/30/15       2.15            $M     False   NaN    2.0  1430.0      NaN
# 2   11/12/15       5.60            $M     False   2.0    3.5  2040.0      NaN
# 3   12/11/15       1.50            $M     False   1.0    1.0  1060.0      NaN
# 4    1/15/16  970000.00             $     False   2.0    2.0  1299.0      NaN
#
#   LotSizeUnit  BuiltInYear
# 0         NaN       1980.0
# 1        sqft       1948.0
# 2        sqft       1976.0
# 3         NaN       1930.0
# 4         NaN       1993.0

# %%
df[df.LotSizeUnit == "ac"].head()
# Out:
#             ID                              Address  Latitude  Longitude  \
# 106   15080894  2950 Pacific Ave, San Francisco, CA  37792769 -122444342
# 138   15089098       22 22nd Ave, San Francisco, CA  37786828 -122481673
# 783   79844263        555 4th St, San Francisco, CA  37779422 -122396712
# 933  124865970  255 Woodside Ave, San Francisco, CA  37746208 -122454769
#
#     DateOfSale  SalePrice SalePriceUnit IsAStudio  Beds  Baths     Size  \
# 106   11/25/15      16.00            $M     False   7.0    6.5  11500.0
# 138   11/17/15       4.97            $M     False   5.0    5.0   5610.0
# 783   11/16/15  788000.00             $     False   1.0    1.0    670.0
# 933   11/16/15      24.90            $M       NaN   NaN    NaN      NaN
#
#           LotSize LotSizeUnit  BuiltInYear
# 106  5.312926e+08          ac       1907.0
# 138  6.071916e+08          ac       1926.0
# 783  1.897474e+09          ac       2006.0
# 933  2.087221e+09          ac       1900.0

# %% [markdown]
# ### `.to_datetime()`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)

# %%
df.DateOfSale

# %% [markdown]
# So far, the dates stored in the `DataFrame` are just strings.  We cannot easily extract the day, month, year.  Thanksfully, `pandas` provides some facilities to do so.

# %%
pd.to_datetime(df.DateOfSale)

# %%
df.DateOfSale = pd.to_datetime(df.DateOfSale)

# %% [markdown]
# ### `.apply()`

# %% [markdown]
# (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.apply.html)

# %%
df.DateOfSale.apply(lambda date_of_sale: date_of_sale.year)

# %%
df['YearOfSale'] = df.DateOfSale.apply(lambda date_of_sale: date_of_sale.year)
df['MonthOfSale'] = df.DateOfSale.apply(lambda date_of_sale: date_of_sale.month)
df['DayOfSale'] = df.DateOfSale.apply(lambda date_of_sale: date_of_sale.day)
df['WeekDayOfSale'] = df.DateOfSale.apply(lambda date_of_sale: date_of_sale.weekday_name)

df.drop('DateOfSale', axis = 1, inplace = True)

# %% [markdown]
# Now, we have the day, day of the week, month, and year of the sale as features in our dataset.

# %%
df
